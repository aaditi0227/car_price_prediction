# %% [markdown]
# <a href="https://colab.research.google.com/github/aaditi0227/car_price_prediction/blob/main/smartchatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#description: This is a 'smart' chat bot program.

# %%
pip install nltk

# %%
pip install newspaper3k
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 6.0 MB/s eta 0:00:00
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13540 sha256=9ecab2fba1725f6a5a0e8c48dd94ce0ae755d359a1afb60f653d4783345d33c8
#   Stored in directory: /root/.cache/pip/wheels/a5/91/9f/00d66475960891a64867914273fcaf78df6cb04d905b104a2a
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3341 sha256=3b1da08f0e26036138da8c922888439b599c8a0e4367b490b0db11079f007a6d
# ...

# %%
pip install lxml_html_clean

# %%
from newspaper import Article
import random
import string
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#Download the punkt package
nltk.download('punkt', quiet=True)
# Out:
# True

# %%
#Get the article
article = Article('https://www.medicalnewstoday.com/articles/168266#taking-a-temperature')
article.download()
article.parse()
article.nlp()
corpus = article.text

# %%
#print the articles text
print(corpus)
# Out:
# Read on to learn more about the symptoms of a fever, as well as some causes and treatment options.
#
# As a person’s body temperature increases, they may feel cold until it levels off and stops rising. People describe this as “chills.”
#
# When an infection occurs, the immune system will launch an attack to try to remove the cause. A high body temperature is sometimes part of this reaction.
#
# If an adult’s body temperature rises above the typical range of 98 to 100°F (36 to 38°C), they may have a fever. This is a common sign of an infection.
#
# Fever is distinct from temporary rises in body temperature due to other factors, such as exercise or hot weather.
#
# Depending on the cause, people may also have other symptoms such as:
#
# A fever is a higher-than-typical body temperature that occurs as part of the immune response. A person may have a fever if:
#
# People can test for fever at home by using a digital thermometer. To use one:
#
# ...

# %%
#tokenization
text = corpus
sentence_list = nltk.sent_tokenize(text) #A list of sentences

# %%
#print the list of sentences
print(sentence_list)
# Out:
# ['Read on to learn more about the symptoms of a fever, as well as some causes and treatment options.', 'As a person’s body temperature increases, they may feel cold until it levels off and stops rising.', 'People describe this as “chills.”\n\nWhen an infection occurs, the immune system will launch an attack to try to remove the cause.', 'A high body temperature is sometimes part of this reaction.', 'If an adult’s body temperature rises above the typical range of 98 to 100°F (36 to 38°C), they may have a fever.', 'This is a common sign of an infection.', 'Fever is distinct from temporary rises in body temperature due to other factors, such as exercise or hot weather.', 'Depending on the cause, people may also have other symptoms such as:\n\nA fever is a higher-than-typical body temperature that occurs as part of the immune response.', 'A person may have a fever if:\n\nPeople can test for fever at home by using a digital thermometer.', 'To use one:\n\nClean the tip using cold water and
# ...

# %%
# Helper function to sort indices based on similarity scores
def index_sort(list_var):
  length = len(list_var)
  list_index = list(range(0, length))

  x = list_var
  for i in range(length):
    for j in range(length):
      if x[list_index[i]] > x[list_index[j]]:
        temp = list_index[i]
        list_index[i] = list_index[j]
        list_index[j] = temp
  return list_index

# Function to return a random greeting response
def greeting_response(text):
  text = text.lower()

  # Bots greeting response
  bot_greetings = ['howdy', 'hi', 'hey', 'hello', 'hola']

  # User greeting response
  user_greetings = ['hi', 'hey', 'hello', 'hola', 'greetings', 'wassup']

  for word in text.split():
    if word in user_greetings:
      return random.choice(bot_greetings)

# Function to create the bot's response based on user input
def bot_response(user_input):
 user_input = user_input.lower()
 sentence_list.append(user_input)
 bot_response = ''
 cm = CountVectorizer().fit_transform(sentence_list)
 similarity_scores = cosine_similarity(cm[-1], cm)
 similarity_scores_list = similarity_scores.flatten()
 index = index_sort(similarity_scores_list)
 index = index[1:]
 response_flag = 0

 j = 0
 for i in range(len(index)):
  if similarity_scores_list[index[i]] > 0.0:
    bot_response = bot_response+' '+sentence_list[index[i]]
    response_flag = 1
    j = j+1
    if j > 2:
      break

  if response_flag == 0:
    bot_response = bot_response+' '+"I apologize, I don't understand."

  sentence_list.remove(user_input)

  return bot_response

# %%
#function to return a random greeting response
def greeting_response(text):
  text = text.lower()

  #bots greeting response
  bot_greetings = ['howdy', 'hi', 'hey', 'hello', 'hola']

  #user greeting response
  user_greetings = ['hi', 'hey', 'hello', 'hola', 'greetings', 'wassup']

  for word in text.split():
    if word in user_greetings:
      return random.choice(bot_greetings)

# %%
def index_sort(list_var):
  length = len(list_var)
  list_index = list(range(0, length))

  x = list_var
  for i in range(length):
    for j in range(length):
      if x[list_index[i]] > x[list_index[j]]:
        temp = list_index[i]
        list_index[i] = list_index[j]
        list_index[j] = temp
  return list_index

# %%
#create the bots response
def bot_response(user_input):
 user_input = user_input.lower()
 sentence_list.append(user_input)
 bot_response = ''
 cm = CountVectorizer().fit_transform(sentence_list)
 similarity_scores = cosine_similarity(cm[-1], cm)
 similarity_scores_list = similarity_scores.flatten()
 index = index_sort(similarity_scores_list)
 index = index[1:]
 response_flag = 0

 j = 0
 for i in range(len(index)):
  if similarity_scores_list[index[i]] > 0.0:
    bot_response = bot_response+' '+sentence_list[index[i]]
    response_flag = 1
    j = j+1
    if j > 2:
      break

  if response_flag == 0:
    bot_response = bot_response+' '+"I apologize, I don't understand."

  sentence_list.remove(user_input)

  return bot_response

# %%
import random
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Helper function to sort indices based on similarity scores
def index_sort(list_var):
  length = len(list_var)
  list_index = list(range(0, length))

  x = list_var
  for i in range(length):
    for j in range(length):
      if x[list_index[i]] > x[list_index[j]]:
        temp = list_index[i]
        list_index[i] = list_index[j]
        list_index[j] = temp
  return list_index

# Function to return a random greeting response
def greeting_response(text):
  text = text.lower()

  # Bots greeting response
  bot_greetings = ['howdy', 'hi', 'hey', 'hello', 'hola']

  # User greeting response
  user_greetings = ['hi', 'hey', 'hello', 'hola', 'greetings', 'wassup']

  for word in text.split():
    if word in user_greetings:
      return random.choice(bot_greetings)

# Function to create the bot's response based on user input
def bot_response(user_input):
 user_input = user_input.lower()
 sentence_list.append(user_input)
 bot_response = ''
 cm = CountVectorizer().fit_transform(sentence_list)
 similarity_scores = cosine_similarity(cm[-1], cm)
 similarity_scores_list = similarity_scores.flatten()
 index = index_sort(similarity_scores_list)
 index = index[1:]
 response_flag = 0

 j = 0
 for i in range(len(index)):
  if similarity_scores_list[index[i]] > 0.0:
    bot_response = bot_response+' '+sentence_list[index[i]]
    response_flag = 1
    j = j+1
    if j > 2:
      break

  if response_flag == 0:
    bot_response = bot_response+' '+"I apologize, I don't understand."

  sentence_list.remove(user_input)

  return bot_response

#start the chat
print('Chat bot: i am  chat bot for short. i will answer your queries for now')

exit_list = ['exit', 'see you later', 'bye', 'quit', 'break']

while(True):
      user_input = input()
      if user_input.lower() in exit_list:
        print('Chat bot: Chat with you later!')
        break
      else:
        if greeting_response(user_input) != None:
          print('Chat bot: '+greeting_response(user_input))
        else:
          print('Chat bot: '+bot_response(user_input))
# Out:
# Chat bot: i am  chat bot for short. i will answer your queries for now
# hi
# Chat bot: howdy
# hey
# Chat bot: hi
# could you tell me about symptoms of a fever
# Chat bot:  Read on to learn more about the symptoms of a fever, as well as some causes and treatment options.
# tell me about  an adult’s body temperature
# Chat bot:  If an adult’s body temperature rises above the typical range of 98 to 100°F (36 to 38°C), they may have a fever.
# hjklghj
# Chat bot:  I apologize, I don't understand.
# bye
# Chat bot: Chat with you later!
